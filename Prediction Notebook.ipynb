# %%
import pandas as pd

# %%
iplBall = pd.read_csv('./DataSet/IPL_Ball_by_Ball_2008_2022.csv')
iplMatch = pd.read_csv('./DataSet/IPL_Matches_Result_2008_2022.csv')

# %%
iplBall.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
iplMatch.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
mergedf = pd.merge(iplBall, iplMatch,on='ID')

# %%
mergedf
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  ...  SuperOver  \
# ...

# %%
mergedf.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  ...     WinningTeam  \
# 0   JC Buttler        NaN            0           0  ...  Gujarat Titans
# 1   JC Buttler    legbyes            0           1  ...  Gujarat Titans
# 2  YBK Jaiswal        NaN            1           0  ...  Gujarat Titans
# 3   JC Buttler        NaN            0           0  ...  Gujarat Titans
# 4   JC Buttler        NaN            0           0  ...  Gujarat Titans
#
#      WonBy  Margin method Player_of_Match  \
# 0  Wickets     7.0    NaN       HH Pandya
# ...

# %%
mergedf['total_runs_scored'] = mergedf['batsman_run'] + mergedf['extras_run']

# %%
innings_df = mergedf.groupby(['ID', 'innings'])['total_runs_scored'].sum().unstack()

# %%
innings_df.tail()
# Out:
# innings      1      2   3   4   5   6
# ID
# 1304116  157.0  160.0 NaN NaN NaN NaN
# 1312197  188.0  191.0 NaN NaN NaN NaN
# 1312198  207.0  193.0 NaN NaN NaN NaN
# 1312199  157.0  161.0 NaN NaN NaN NaN
# 1312200  130.0  133.0 NaN NaN NaN NaN

# %%
innings_df
# Out:
# innings      1      2   3   4   5   6  inning1_cumulative_score  \
# ID
# 335982   222.0   82.0 NaN NaN NaN NaN                     222.0
# 335983   240.0  207.0 NaN NaN NaN NaN                     462.0
# 335984   129.0  132.0 NaN NaN NaN NaN                     591.0
# 335985   165.0  166.0 NaN NaN NaN NaN                     756.0
# 335986   110.0  112.0 NaN NaN NaN NaN                     866.0
# ...        ...    ...  ..  ..  ..  ..                       ...
# 1304116  157.0  160.0 NaN NaN NaN NaN                  153609.0
# 1312197  188.0  191.0 NaN NaN NaN NaN                  153797.0
# 1312198  207.0  193.0 NaN NaN NaN NaN                  154004.0
# 1312199  157.0  161.0 NaN NaN NaN NaN                  154161.0
# 1312200  130.0  133.0 NaN NaN NaN NaN                  154291.0
#
# innings  inning2_cumulative_score  inning3_cumulative_score  \
# ID
# 335982                       82.0                       NaN
# 335983                      289.0                       NaN
# ...

# %%
X = innings_df[['inning1_cumulative_score', 'inning2_cumulative_score']]
y = innings_df['total_runs_scored']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_runs_scored'
#
# The above exception was the direct cause of the following exception:
#
# ...
